# %%
# %pip install pycaret
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
air_data = pd.read_csv('C:\\Users\\ASUS\\Desktop\\VS code\\PsuTerm02\\241-152\\final_project\\data_mange\\data_model_air4thai_44t_2023-01-01_2024-02-27.csv')
air_data = air_data.drop(['Unnamed: 0'], axis=1, inplace=False)#data_for_train = df_airthai.drop(['Unnamed: 0', 'Unnamed: 0.1', 'DATETIMEDATA', 'stationID'], axis=1, inplace=False)
air_data
# Out:
#       PM25         O3  WS  TEMP  RH   WD
# 0     16.5  16.000000   1  27.0  79  115
# 1     33.6   0.000000   1  27.0  82   97
# 2     34.2   0.000000   1  26.0  84   96
# 3     20.1   0.000000   1  26.0  82  108
# 4     16.5   1.000000   1  27.0  79  106
# ...    ...        ...  ..   ...  ..  ...
# 1109  12.8  16.000000   1  27.0  78  115
# 1110  19.9  11.415652   1  27.0  79   99
# 1111  19.9   0.000000   1  27.0  76  106
# 1112  20.4  17.000000   1  29.0  70  108
# 1113  16.0   1.000000   1  30.0  61  121
#
# [1114 rows x 6 columns]

# %%
from pycaret.regression import *
s = setup(air_data, target = 'PM25', session_id = 123)
# Out:
# <style type="text/css">
# #T_d2789_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d2789">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2789_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d2789_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2789_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d2789_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d2789_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_d2789_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d2789_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d2789_row1_col1" class="data row1 col1" >PM25</td>
#     </tr>
#     <tr>
#       <th id="T_d2789_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_func = compare_models()
# Out:
# <style type="text/css">
# #T_2cacf th {
#   text-align: left;
# }
# ...

# %%
plot_model(best_func, plot = 'feature')

# %%
predict_model(best_func)
# Out:
# <style type="text/css">
# </style>
# <table id="T_71869">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71869_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_71869_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_71869_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_71869_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_71869_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_71869_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_71869_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71869_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_71869_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_71869_row0_col1" class="data row0 col1" >3.8799</td>
# ...

# %%
import pandas as pd
air_data_test = pd.read_csv('C:\\Users\\ASUS\\Desktop\\VS code\\PsuTerm02\\241-152\\final_project\\data_mange\\data_test_air4thai_44t_2023-01-01_2024-02-27.csv')
air_data_test = air_data_test.drop(['Unnamed: 0'], axis=1, inplace=False)
air_data_test
# Out:
#      PM25   O3  WS  TEMP  RH   WD
# 0    19.2  9.0   1  31.0  54  152
# 1    15.8  6.0   1  32.0  52  188
# 2    16.2  4.0   1  32.0  50  222
# 3    14.4  0.0   1  33.0  47  204
# 4    18.2  2.0   1  33.0  47  147
# ..    ...  ...  ..   ...  ..  ...
# 273  21.7  9.0   1  29.0  67  162
# 274  17.5  1.0   1  29.0  68  134
# 275  21.1  0.0   1  29.0  69  140
# 276  23.2  0.0   1  29.0  70  111
# 277  16.2  8.0   1  28.0  71  120
#
# [278 rows x 6 columns]

# %%
predict_model(best_func, data=air_data_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_23b87">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23b87_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_23b87_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_23b87_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_23b87_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_23b87_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_23b87_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_23b87_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23b87_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_23b87_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_23b87_row0_col1" class="data row0 col1" >4.2004</td>
# ...
